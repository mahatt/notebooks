# %% [markdown]
# # Digital Marketing
# ![image.png](attachment:image.png)

# %% [markdown]
# * Outbound - firm reaching out consumer , display ad , Search Ads, Search Engine Marketing
# * Inbound - SEO, search keyword
#
# * CPC - cost per click , amount firm bids on keyword
