# %% [markdown]
# ## Formulation
# + Business Strategy
# + Corporate Strategy
# + Global Strategy
# ![image.png](attachment:image.png)
# ## Implementation
# + Organizational Design
# + Corporate Governance and Business Ethics
