# %% [markdown]
# # Competitive Advantage Analysis
# ### Competitive Advantage and Firm Performance
# * defined as superior performance relative to other competitors in the same industry or to the industry average
# * three frameworks to capture the multifaceted nature of competitive advantage
#   - traditional frameworks
#     + Accounting profitability
#         * Task for leaders
#             + Assess the performance of their firm accurately
#             +   Compare and benchmark their firm’s performance to other competitors in the same industry or against the industry average
#             + ROCI = firm profitability, ROIC is greater than its cost of capital, it generates value
#             + ROE =
#             + ROR
#             + ROA
#
#          *  Limitations of Accounting Data
#              + historical and  backward-looking. (market disruptions)
#              + Accounting data do not consider off–balance sheet items (ROA for rented and owned assets)
#              +  focus mainly on tangible assets
#
#     + Shareholder value creation.
#         - risk capital: The money provided by shareholders in exchange for an equity share in a company; it cannot be recovered if the firm goes bankrupt.
#         - total return to shareholders : Return on risk capital that includes stock price appreciation plus dividends received over a specific period.
#         - market capitalization : A firm performance metric that captures the total dollar market value of a company’s total outstanding shares at any given point in time.
#         - Limitations
#              + Stock prices can be highly volatile, making it difficult to assess firm performance
#              + Overall macroeconomic factors such as economic growth or contraction, the unemployment rate, and interest and exchange rates all have a direct bearing on stock prices
#              + Stock prices frequently reflect the psychological mood of investors, which can at times be irrational.
#
#     + Economic value creation
#         - Difference between value (V) and cost (C), or (V – C).
#         - reservation price :  The maximum price a consumer is willing to pay for a product or service based on the total perceived consumer benefits.
#         - Value : e dollar amount (V) a consumer attaches to a good or service; the consumer’s maximum willingness to pay;
#         - producer surplus : e difference between price charged (P) and the cost to produce (C), or (P – C); also called profit.
#         ![image.png](attachment:image.png)
#         - opportunity costs : The value of the best forgone alternative use of the resources employed.
#       ![image-2.png](attachment:image-2.png)
#         - limitation
#             + Determining the value of a good in the eyes of consumers is not a simple task.
#             + The value of a good in the eyes of consumers changes based on income, preferences, time, and other factors.
#             + To measure firm-level competitive advantage, we must estimate the economic value created for all products and services offered by the firm

# %% [markdown]
#   - integrative frameworks
#      + The balanced scorecard
#          - Strategy implementation tool that harnesses multiple internal and external performance metrics in order to balance financial and strategic goals.
#     ![image.png](attachment:image.png)
#     ![image-2.png](attachment:image-2.png)
#          - Con : e balanced scorecard is a tool for strategy implementation, not for strategy formulation
#      + The triple bottom line
#         - Profits. The economic dimension captures the necessity of businesses to be profitable to survive.
#         - People. The social dimension emphasizes the people aspect
#         - Planet. The ecological dimension emphasizes the relationship between business and the natural environment.
#         ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Business Models: Putting Strategy into Action
# * Stipulates how the firm conducts its business with its buyers, suppliers, and partners in order to make money.
#
# #### The Why, What, Who, and How of Business Models Framework
# ![image.png](attachment:image.png)
#
#
# #### Popular Business Models
# ■ Razor–razor-blades
# ■ Subscription
# ■ Pay-as-you-go
# ■ Freemium
# ■ Ultra Low cost
# ■ Wholesale
# ■ Agency
# ■ Bundling
# ### Dynamic Nature of Business Models
# * evolve and combinations and permutations
# * Combination
# * Evolution
# * disruption
# * Response to disruption
# * Legal Conflicts
