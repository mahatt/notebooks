# %%
import pandas as pd
all_table = pd.read_csv(r'loan50.csv')
all_table.head(31)
# Out:
#    state emp_length term homeownership annual_income  verified_income
# 0     NJ          3   60          rent         59000     Not Verified  \
# 1     CA         10   36          rent         60000     Not Verified
# 2     SC        NaN   36      mortgage         75000         Verified
# 3     CA          0   36          rent         75000     Not Verified
# 4     OH          4   60      mortgage        254000     Not Verified
# 5     IN          6   36      mortgage         67000  Source Verified
# 6     NY          2   36          rent         28800  Source Verified
# 7     MO         10   36      mortgage         80000     Not Verified
# 8     FL          6   60          rent         34000     Not Verified
# 9     FL          3   60      mortgage         80000  Source Verified
# 10    MD          8   36          rent         73000  Source Verified
# 11    HI         10   36      mortgage        120000     Not Verified
# ...

# %%
all_table.describe()
# Out:
#        debt_to_income  total_credit_limit  total_credit_utilized
# count       50.000000           50.000000              50.000000  \
# mean         0.722643       208546.640000           61546.540000
# std          0.958264       167514.864327           63778.074324
# min          0.054724        15980.000000            2872.000000
# 25%          0.266424        70526.250000           25693.500000
# 50%          0.540471       147363.500000           48005.500000
# 75%          0.741217       299766.250000           76796.250000
# max          5.333729       793009.000000          373361.000000
#
#        num_cc_carrying_balance  interest_rate  public_record_bankrupt
# count                50.000000      50.000000               50.000000  \
# mean                  5.060000      11.567200                0.080000
# std                   2.999388       5.052115                0.274048
# min                   1.000000       5.310000                0.000000
# ...

# %%
all_table['interest_rate'].value_counts()
# Out:
# interest_rate
# 9.92     4
# 10.91    3
# 7.96     3
# 9.44     3
# 17.09    3
# 6.08     3
# 12.62    3
# 10.42    2
# 9.93     2
# 10.90    2
# 6.71     2
# 5.31     2
# 9.43     2
# 7.35     2
# 18.45    1
# 7.34     1
# 11.98    1
# 15.04    1
# 16.02    1
# 19.42    1
# 5.32     1
# 20.00    1
# 14.08    1
# 18.06    1
# 24.85    1
# 7.97     1
# 26.30    1
# 21.45    1
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
all_table['interest_rate'].value_counts().plot(kind='box', vert=True, figsize=(14,6))
# Out:
# <Axes: >

# %%
corr = all_table.corr(numeric_only=True)
# Out:
#                          debt_to_income  total_credit_limit
# debt_to_income                 1.000000            0.018352  \
# total_credit_limit             0.018352            1.000000
# total_credit_utilized          0.914062            0.241007
# num_cc_carrying_balance       -0.064145            0.177586
# interest_rate                  0.129815           -0.075827
# public_record_bankrupt        -0.028159            0.077946
# total_income                  -0.226439            0.632899
# Unnamed: 18                         NaN                 NaN
# annual_income.1               -0.155610            0.686180
# loan_amount.1                 -0.237854            0.464447
#
#                          total_credit_utilized  num_cc_carrying_balance
# debt_to_income                        0.914062                -0.064145  \
# total_credit_limit                    0.241007                 0.177586
# total_credit_utilized                 1.000000                -0.063331
# ...

# %%
corr = all_table.corr(numeric_only=True)

fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
all_table.plot(kind='scatter', x='total_credit_limit', y='total_credit_utilized', figsize=(6,6))
# Out:
# <Axes: xlabel='total_credit_limit', ylabel='total_credit_utilized'>

# %%
all_table[all_table['homeownership']== 'rent'].head()
# Out:
#   state emp_length term homeownership annual_income  verified_income
# 0    NJ          3   60          rent         59000     Not Verified  \
# 1    CA         10   36          rent         60000     Not Verified
# 3    CA          0   36          rent         75000     Not Verified
# 6    NY          2   36          rent         28800  Source Verified
# 8    FL          6   60          rent         34000     Not Verified
#
#    debt_to_income  total_credit_limit  total_credit_utilized
# 0        0.557525             95131.0                32894.0  \
# 1        1.305683             51929.0                78341.0
# 3        0.574347             59890.0                43076.0
# 6        0.099722             15980.0                 2872.0
# 8        0.697500             87705.0                23715.0
#
#    num_cc_carrying_balance  ... loan_amount grade interest_rate
# 0                      8.0  ...       22000     B         10.90  \
# ...
